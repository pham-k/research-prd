# %%
import pandas as pd
from pathlib import Path

# %%
ext = Path('/home/kyo/Documents/project/prd/data/external')
inter = Path('/home/kyo/Documents/project/prd/data/intermediate')
s = 'NguVoiBaMe	NguRieng	NguRiengTuoi	NguVoiPet	Lop	SiSoLop	TruongAnTrua	TruongUong	TruongTieuTien	TruongDaiTien	TruongNgu'
k = s.split('	')
v = ['Int64']*64
dtype = {k:v for (k, v) in zip(s.split('	'), v)}
dtype['V1'] = 'string'

df = pd.read_csv(
    ext / 'prd_v2.0.0_Form2.csv',
    usecols = [*dtype],
    dtype = dtype,
    index_col = 'V1'
)

# %%
df[df.loc[:, df.columns != 'NguRiengTuoi'].isna().any(axis=1)]
# Out:
#         NguVoiBaMe  NguRieng  NguRiengTuoi  NguVoiPet   Lop  SiSoLop  \
# V1
# 219009           1         0          <NA>          0     1     <NA>
# 219012           1         0          <NA>          0     2     <NA>
# 319001           1         0          <NA>          0     7     <NA>
# 319048           1         0          <NA>          0     2     <NA>
# 319055           1         0          <NA>          0     6     <NA>
# 319061           1         0          <NA>          0  <NA>       52
# 319080           1         0          <NA>          0  <NA>     <NA>
# 319084           1         0          <NA>          0     4     <NA>
# 319089           1         0          <NA>          0     0     <NA>
# 319091           1         0          <NA>          0     5     <NA>
# 319140           1         1             3          0     3     <NA>
# 519001           1         0          <NA>          0     0       25
# ...

# %%
df[(df.NguRieng == 1) & (df.NguRiengTuoi.isna())]
# Out:
#         NguVoiBaMe  NguRieng  NguRiengTuoi  NguVoiPet  Lop  SiSoLop  \
# V1
# 219004           1         1          <NA>          0    5       39
# 519026           1         1          <NA>          0    9     <NA>
#
#         TruongAnTrua  TruongUong  TruongTieuTien  TruongDaiTien  TruongNgu
# V1
# 219004             0           1               1              0          0
# 519026             0           0               1              0          0

# %%
df.to_excel(inter / 'form2ef.xlsx')
