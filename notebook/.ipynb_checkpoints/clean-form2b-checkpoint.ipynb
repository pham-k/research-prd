# %%
import pandas as pd
from pathlib import Path

# %%
ext = Path('/home/kyo/Documents/project/prd/data/external')
inter = Path('/home/kyo/Documents/project/prd/data/intermediate')
s = 'TANong	TAChua	TACay	TASong	TANuong	TAHanhToi	TADuongPho	TAHangQuan	TANhanh	AnBoc	AnVat	AnChung	UongChung	ChamChung	GapChung'
k = s.split('	')
v = ['Int64']*64
dtype = {k:v for (k, v) in zip(s.split('	'), v)}
dtype['V1'] = 'string'

df = pd.read_csv(
    ext / 'prd_v2.0.0_Form2.csv',
    usecols = [*dtype],
    dtype = dtype,
    index_col = 'V1'
)

# %%
df[df.isna().any(axis=1)]
# Out:
#         TANong  TAChua  TACay  TASong  TANuong  TAHanhToi  TADuongPho  \
# V1
# 519001       0       1      0       0        1          0           1
# 519012       0       0      0       0        1          0           1
# 519034       0       0      0       0        0          0           0
# 319214       3       1   <NA>       0        1          0           0
# 319212       0       0      0       0        0          0           0
# 319219    <NA>       0      0       0        2          0           1
# 319221       1       1      1       0        1          0           1
# 319238    <NA>       2   <NA>       0        2          0        <NA>
# 519079       0       0      0       0     <NA>          0           0
#
#         TAHangQuan  TANhanh  AnBoc  AnVat  AnChung  UongChung  ChamChung  \
# V1
# 519001           2        1      0   <NA>        1          1          1
# 519012           0     <NA>      0      1        0          1          1
# 519034           0        3      0      0        1          1       <NA>
# 319214           1        1      0      0        1          0          0
# 319212           1        1   <NA>      1        0          0          0
# 319219           0        1      0      2        0          0          1
# 319221           1        1   <NA>      2        0          1          1
# 319238           3        2      0      2        0          0          1
# 519079           0        0      0      3        0          1          0
#
#         GapChung
# V1
# 519001         1
# 519012         1
# 519034         0
# 319214         0
# 319212         0
# 319219         1
# 319221         1
# 319238         1
# 519079         0

# %%
df.to_excel(inter / 'form2b.xlsx')
