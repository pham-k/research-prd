# %%
import pandas as pd
from pathlib import Path

# %%
ext = Path('/home/kyo/Documents/project/prd/data/external')
inter = Path('/home/kyo/Documents/project/prd/data/intermediate')
dtype = {
    'V1': 'string',
    'ConThu': 'Int64',
    'TuoiThai': 'Int64',
    'TuoiThaiTT': 'Int64',
    'PPSanh': 'Int64',
    'CNLS': 'float',
    'BuMe': 'float',
    'AnDam': 'float',
    'NhaiMom': 'Int64',
    'TCMR': 'Int64',
    'DiHocThang': 'Int64',
    'DiHocTuoi': 'Int64',
}

df = pd.read_csv(
    ext / 'prd_v2.0.0_Form2.csv',
    usecols = [*dtype],
    dtype = dtype,
    index_col = 'V1'
)

# %%
df[df.ConThu.isna()]
# Out:
# Empty DataFrame
# Columns: [ConThu, TuoiThai, TuoiThaiTT, PPSanh, CNLS, BuMe, AnDam, NhaiMom, TCMR, DiHocThang, DiHocTuoi]
# Index: []

# %%
df[df.TuoiThai.isna()]
# Out:
# Empty DataFrame
# Columns: [ConThu, TuoiThai, TuoiThaiTT, PPSanh, CNLS, BuMe, AnDam, NhaiMom, TCMR, DiHocThang, DiHocTuoi]
# Index: []

# %%
df[(df.TuoiThai == 2) & (df.TuoiThaiTT.isna())]
# Out:
#         ConThu  TuoiThai  TuoiThaiTT  PPSanh  CNLS  BuMe  AnDam  NhaiMom  \
# V1
# 519043       1         2        <NA>       2   2.7   4.0    4.0        1
#
#         TCMR  DiHocThang  DiHocTuoi
# V1
# 519043     1        <NA>          6

# %%
df[df.PPSanh.isna()]
# Out:
#         ConThu  TuoiThai  TuoiThaiTT  PPSanh  CNLS  BuMe  AnDam  NhaiMom  \
# V1
# 319008       1         1        <NA>    <NA>  3.05  24.0   28.0        1
#
#         TCMR  DiHocThang  DiHocTuoi
# V1
# 319008     1        <NA>          4

# %%
df[df.CNLS.isna()]
# Out:
#         ConThu  TuoiThai  TuoiThaiTT  PPSanh  CNLS  BuMe  AnDam  NhaiMom  \
# V1
# 519068       1         1        <NA>       1   NaN  12.0    6.0        0
# 519076       2         1        <NA>       1   NaN  20.0    5.0        0
# 519089       2         1        <NA>       1   NaN   1.0    6.0        1
#
#         TCMR  DiHocThang  DiHocTuoi
# V1
# 519068     1        <NA>          5
# 519076     1        <NA>          3
# 519089     1        <NA>          4

# %%
df[df.BuMe.isna()]
# Out:
#         ConThu  TuoiThai  TuoiThaiTT  PPSanh  CNLS  BuMe  AnDam  NhaiMom  \
# V1
# 219005       2         1        <NA>       2   3.3   NaN    3.0        0
# 219014       3         1        <NA>       1   3.6   NaN    6.0        0
# 319042       1         1        <NA>       1   3.8   NaN    5.0        1
# 319045       1         1        <NA>       2   3.2   NaN    6.0        0
# 519004       1         1        <NA>       1   3.0   NaN    6.0        0
# 519031       1         1        <NA>       1   2.7   NaN    8.0        0
# 319224       1         1        <NA>       2   3.5   NaN    NaN       98
# 319219       1         1        <NA>       2   2.9   NaN    NaN        0
# 519082       1         1        <NA>       3   3.1   NaN    6.0        0
#
#         TCMR  DiHocThang  DiHocTuoi
# V1
# 219005     0          12       <NA>
# 219014     1        <NA>          4
# 319042     1        <NA>          3
# 319045     1          10       <NA>
# 519004    98        <NA>          3
# 519031     1          24       <NA>
# 319224     1          42       <NA>
# 319219     1        <NA>          3
# 519082     1           3       <NA>

# %%
df[df.AnDam.isna()]
# Out:
#         ConThu  TuoiThai  TuoiThaiTT  PPSanh  CNLS  BuMe  AnDam  NhaiMom  \
# V1
# 319015       2         1        <NA>       2   3.2  12.0    NaN        0
# 319089       1         1        <NA>       1   3.4  18.0    NaN        0
# 319224       1         1        <NA>       2   3.5   NaN    NaN       98
# 319236       1         1        <NA>       1   3.4  12.0    NaN        0
# 319193       1         1        <NA>       1   2.9  24.0    NaN        0
# 319219       1         1        <NA>       2   2.9   NaN    NaN        0
#
#         TCMR  DiHocThang  DiHocTuoi
# V1
# 319015     1        <NA>          3
# 319089     1          13       <NA>
# 319224     1          42       <NA>
# 319236     1        <NA>          2
# 319193     1        <NA>          4
# 319219     1        <NA>          3

# %%
df[df.NhaiMom.isna()]
# Out:
# Empty DataFrame
# Columns: [ConThu, TuoiThai, TuoiThaiTT, PPSanh, CNLS, BuMe, AnDam, NhaiMom, TCMR, DiHocThang, DiHocTuoi]
# Index: []

# %%
df[df.TCMR.isna()]
# Out:
# Empty DataFrame
# Columns: [ConThu, TuoiThai, TuoiThaiTT, PPSanh, CNLS, BuMe, AnDam, NhaiMom, TCMR, DiHocThang, DiHocTuoi]
# Index: []

# %%
df[(df.DiHocThang.isna()) & (df.DiHocTuoi.isna())]
# Out:
#         ConThu  TuoiThai  TuoiThaiTT  PPSanh  CNLS  BuMe  AnDam  NhaiMom  \
# V1
# 319001       1         1        <NA>       1   3.0  14.0    6.0        1
# 319080       1         1        <NA>       2   3.5  23.0    6.0        0
# 519002       1         2          36       1   2.9  18.0    6.0        1
#
#         TCMR  DiHocThang  DiHocTuoi
# V1
# 319001     1        <NA>       <NA>
# 319080     1        <NA>       <NA>
# 519002     1        <NA>       <NA>

# %%
df.to_excel(inter / 'form2a.xlsx')
